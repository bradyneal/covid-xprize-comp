# %% [markdown]
# Checks whether the most recent dates are the same for each region.

# %%
import os
import pandas as pd
import numpy as np

# %%
current_dir = os.path.abspath('')  #./ongoing/prescriptors
ROOT_DIR =  os.path.abspath(os.path.join(current_dir, os.pardir))  # ./ongoing
DATA_PATH = os.path.join(ROOT_DIR, 'data')
DATA_FILE_PATH = os.path.join(DATA_PATH, 'OxCGRT_latest.csv')
ADDITIONAL_CONTEXT_FILE = os.path.join(DATA_PATH, "Additional_Context_Data_Global.csv")
ADDITIONAL_US_STATES_CONTEXT = os.path.join(DATA_PATH, "US_states_populations.csv")
ADDITIONAL_UK_CONTEXT = os.path.join(DATA_PATH, "uk_populations.csv")

# %%
NPI_COLUMNS = ['C1_School closing',
               'C2_Workplace closing',
               'C3_Cancel public events',
               'C4_Restrictions on gatherings',
               'C5_Close public transport',
               'C6_Stay at home requirements',
               'C7_Restrictions on internal movement',
               'C8_International travel controls',
               'H1_Public information campaigns',
               'H2_Testing policy',
               'H3_Contact tracing',
               'H6_Facial Coverings']

CONTEXT_COLUMNS = ['CountryName',
                   'RegionName',
                   'GeoID',
                   'Date',
                   'ConfirmedCases',
                   'ConfirmedDeaths',
                   'Population']
NB_LOOKBACK_DAYS = 21
NB_TEST_DAYS = 14
WINDOW_SIZE = 7
US_PREFIX = "United States / "
# NUM_TRIALS = 1
NUM_TRIALS = 10
LSTM_SIZE = 32
MAX_NB_COUNTRIES = 20

# %%
# load data
df = pd.read_csv(DATA_FILE_PATH,
                 parse_dates=['Date'],
                 encoding="ISO-8859-1",
                 dtype={"RegionName": str,
                        "RegionCode": str},
                 error_bad_lines=False)
df["GeoID"] = np.where(df["RegionName"].isnull(),
                           df["CountryName"],
                           df["CountryName"] + ' / ' + df["RegionName"])
df
# Out:
#         Unnamed: 0 CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 0                0       Aruba         ABW        NaN        NaN    NAT_TOTAL
# 1                1       Aruba         ABW        NaN        NaN    NAT_TOTAL
# 2                2       Aruba         ABW        NaN        NaN    NAT_TOTAL
# 3                3       Aruba         ABW        NaN        NaN    NAT_TOTAL
# 4                4       Aruba         ABW        NaN        NaN    NAT_TOTAL
# ...            ...         ...         ...        ...        ...          ...
# 111435      111435    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL
# 111436      111436    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL
# 111437      111437    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL
# 111438      111438    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL
# 111439      111439    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL
#
#              Date  C1_School closing  C1_Flag  C2_Workplace closing  ...  \
# 0      2020-01-01                0.0      NaN                   0.0  ...
# 1      2020-01-02                0.0      NaN                   0.0  ...
# 2      2020-01-03                0.0      NaN                   0.0  ...
# 3      2020-01-04                0.0      NaN                   0.0  ...
# 4      2020-01-05                0.0      NaN                   0.0  ...
# ...           ...                ...      ...                   ...  ...
# 111435 2021-01-28                2.0      1.0                   3.0  ...
# 111436 2021-01-29                2.0      1.0                   3.0  ...
# 111437 2021-01-30                2.0      1.0                   3.0  ...
# 111438 2021-01-31                2.0      1.0                   3.0  ...
# 111439 2021-02-01                2.0      1.0                   3.0  ...
#
#         StringencyIndexForDisplay  StringencyLegacyIndex  \
# 0                            0.00                   0.00
# 1                            0.00                   0.00
# 2                            0.00                   0.00
# 3                            0.00                   0.00
# 4                            0.00                   0.00
# ...                           ...                    ...
# 111435                      84.26                  85.71
# 111436                      84.26                  85.71
# 111437                      84.26                  85.71
# 111438                      84.26                  85.71
# 111439                      84.26                  85.71
#
#         StringencyLegacyIndexForDisplay  GovernmentResponseIndex  \
# 0                                  0.00                      0.0
# 1                                  0.00                      0.0
# 2                                  0.00                      0.0
# 3                                  0.00                      0.0
# 4                                  0.00                      0.0
# ...                                 ...                      ...
# 111435                            85.71                     65.0
# 111436                            85.71                     65.0
# 111437                            85.71                     65.0
# 111438                            85.71                     65.0
# 111439                            85.71                     65.0
#
#         GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# 0                                     0.0                    0.00
# 1                                     0.0                    0.00
# 2                                     0.0                    0.00
# 3                                     0.0                    0.00
# 4                                     0.0                    0.00
# ...                                   ...                     ...
# 111435                               65.0                   71.15
# 111436                               65.0                   71.15
# 111437                               65.0                   71.15
# 111438                               65.0                   71.15
# 111439                               65.0                   71.15
#
#         ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# 0                                   0.00                   0.0
# 1                                   0.00                   0.0
# 2                                   0.00                   0.0
# 3                                   0.00                   0.0
# 4                                   0.00                   0.0
# ...                                  ...                   ...
# 111435                             71.15                  25.0
# 111436                             71.15                  25.0
# 111437                             71.15                  25.0
# 111438                             71.15                  25.0
# 111439                             71.15                  25.0
#
#         EconomicSupportIndexForDisplay     GeoID
# 0                                  0.0     Aruba
# 1                                  0.0     Aruba
# 2                                  0.0     Aruba
# 3                                  0.0     Aruba
# 4                                  0.0     Aruba
# ...                                ...       ...
# 111435                            25.0  Zimbabwe
# 111436                            25.0  Zimbabwe
# 111437                            25.0  Zimbabwe
# 111438                            25.0  Zimbabwe
# 111439                            25.0  Zimbabwe
#
# [111440 rows x 51 columns]

# %%
# load additonal contexts data
# File containing the population for each country
# Note: this file contains only countries population, not regions
additional_context_df = pd.read_csv(ADDITIONAL_CONTEXT_FILE,
                                    usecols=['CountryName', 'Population'])

additional_context_df['GeoID'] = additional_context_df['CountryName']

# US states population
additional_us_states_df = pd.read_csv(ADDITIONAL_US_STATES_CONTEXT,
                                      usecols=['NAME', 'POPESTIMATE2019'])
# Rename the columns to match measures_df ones
additional_us_states_df.rename(columns={'POPESTIMATE2019': 'Population'}, inplace=True)
# Prefix with country name to match measures_df
additional_us_states_df['GeoID'] = US_PREFIX + additional_us_states_df['NAME']

# Append the new data to additional_df
additional_context_df = additional_context_df.append(additional_us_states_df)

# UK population
additional_uk_df = pd.read_csv(ADDITIONAL_UK_CONTEXT)
# Append the new data to additional_df
additional_context_df = additional_context_df.append(additional_uk_df)

# %%
additional_context_df
# Out:
#                       CountryName  Population  \
# 0                     Afghanistan    38928346
# 1                         Albania     2877797
# 2                         Algeria    43851044
# 3                         Andorra       77265
# 4                          Angola    32866272
# 5                       Argentina    45195774
# 6                           Aruba      106766
# 7                       Australia    25499884
# 8                         Austria     9006398
# 9                      Azerbaijan    10127874
# 10                        Bahamas      385637
# 11                        Bahrain     1701575
# 12                     Bangladesh   164689383
# 13                       Barbados      287375
# 14                        Belarus     9408400
# 15                        Belgium    11589623
# 16                         Belize      397628
# 17                          Benin    12114193
# 18                        Bermuda       62278
# 9                             NaN    39512223
# 10                            NaN     5758736
# 11                            NaN     3565287
# 12                            NaN      973764
# 13                            NaN      705749
# 14                            NaN    21477737
# 15                            NaN    10617423
# 16                            NaN     1415872
# 17                            NaN     1787065
# 18                            NaN    12671821
# 19                            NaN     6732219
# 20                            NaN     3155070
# 21                            NaN     2913314
# 22                            NaN     4467673
# 23                            NaN     4648794
# 24                            NaN     1344212
# 25                            NaN     6045680
# 26                            NaN     6892503
# 27                            NaN     9986857
# 28                            NaN     5639632
# 29                            NaN     2976149
# 30                            NaN     6137428
# 31                            NaN     1068778
# 32                            NaN     1934408
# 33                            NaN     3080156
# 34                            NaN     1359711
# 35                            NaN     8882190
# 36                            NaN     2096829
# 37                            NaN    19453561
# 38                            NaN    10488084
# 39                            NaN      762062
# 40                            NaN    11689100
# 41                            NaN     3956971
# 42                            NaN     4217737
# 43                            NaN    12801989
# 44                            NaN     1059361
# 45                            NaN     5148714
# 46                            NaN      884659
# 47                            NaN     6829174
# 48                            NaN    28995881
# 49                            NaN     3205958
# 50                            NaN      623989
# 51                            NaN     8535519
# 52                            NaN     7614893
# 53                            NaN     1792147
# 54                            NaN     5822434
# 55                            NaN      578759
# 56                            NaN     3193694
# 57                            NaN      104914
# 0                             NaN    55980000
# 1                             NaN     1882000
# 2                             NaN     5454000
# 3                             NaN     3136000
#
#                                  GeoID              NAME
# 0                          Afghanistan               NaN
# 1                              Albania               NaN
# 2                              Algeria               NaN
# 3                              Andorra               NaN
# 4                               Angola               NaN
# 5                            Argentina               NaN
# 6                                Aruba               NaN
# 7                            Australia               NaN
# 8                              Austria               NaN
# 9                           Azerbaijan               NaN
# 10                             Bahamas               NaN
# 11                             Bahrain               NaN
# 12                          Bangladesh               NaN
# 13                            Barbados               NaN
# 14                             Belarus               NaN
# 15                             Belgium               NaN
# 16                              Belize               NaN
# 17                               Benin               NaN
# 18                             Bermuda               NaN
# 19                              Bhutan               NaN
# 20                             Bolivia               NaN
# 21              Bosnia and Herzegovina               NaN
# 22                            Botswana               NaN
# 23                              Brazil               NaN
# 24                       Brazil / Acre               NaN
# 25                    Brazil / Alagoas               NaN
# 26                      Brazil / Amapa               NaN
# 27                   Brazil / Amazonas               NaN
# 28                      Brazil / Bahia               NaN
# 29                      Brazil / Ceara               NaN
# 30           Brazil / Distrito Federal               NaN
# 31             Brazil / Espirito Santo               NaN
# 32                      Brazil / Goias               NaN
# 33                   Brazil / Maranhao               NaN
# 34                Brazil / Mato Grosso               NaN
# 35         Brazil / Mato Grosso do Sul               NaN
# 36               Brazil / Minas Gerais               NaN
# 37                       Brazil / Para               NaN
# 38                    Brazil / Paraiba               NaN
# 39                     Brazil / Parana               NaN
# 40                 Brazil / Pernambuco               NaN
# 41                      Brazil / Piaui               NaN
# 42        Brazil / Rio Grande do Norte               NaN
# 43          Brazil / Rio Grande do Sul               NaN
# 44             Brazil / Rio de Janeiro               NaN
# 45                   Brazil / Rondonia               NaN
# 46                    Brazil / Roraima               NaN
# 47             Brazil / Santa Catarina               NaN
# 48                  Brazil / Sao Paulo               NaN
# 49                    Brazil / Sergipe               NaN
# 50                  Brazil / Tocantins               NaN
# 51                              Brunei               NaN
# 52                            Bulgaria               NaN
# 53                        Burkina Faso               NaN
# 54                             Burundi               NaN
# 55                            Cambodia               NaN
# 56                            Cameroon               NaN
# 57                              Canada               NaN
# 58                          Cape Verde               NaN
# 59            Central African Republic               NaN
# 60                                Chad               NaN
# 61                               Chile               NaN
# 62                               China               NaN
# 63                            Colombia               NaN
# 64                             Comoros               NaN
# 65                               Congo               NaN
# 66                          Costa Rica               NaN
# 67                       Cote d'Ivoire               NaN
# 68                             Croatia               NaN
# 69                                Cuba               NaN
# 70                              Cyprus               NaN
# 71                      Czech Republic               NaN
# 72        Democratic Republic of Congo               NaN
# 73                             Denmark               NaN
# 74                            Djibouti               NaN
# 75                            Dominica               NaN
# 76                  Dominican Republic               NaN
# 77                             Ecuador               NaN
# 78                               Egypt               NaN
# 79                         El Salvador               NaN
# 80                             Eritrea               NaN
# 81                             Estonia               NaN
# 82                            Eswatini               NaN
# 83                            Ethiopia               NaN
# 84                      Faeroe Islands               NaN
# 85                                Fiji               NaN
# 86                             Finland               NaN
# 87                              France               NaN
# 88                               Gabon               NaN
# 89                              Gambia               NaN
# 90                             Georgia               NaN
# 91                             Germany               NaN
# 92                               Ghana               NaN
# 93                              Greece               NaN
# 94                           Greenland               NaN
# 95                                Guam               NaN
# 96                           Guatemala               NaN
# 97                              Guinea               NaN
# 98                              Guyana               NaN
# 99                               Haiti               NaN
# 100                           Honduras               NaN
# 101                          Hong Kong               NaN
# 102                            Hungary               NaN
# 103                            Iceland               NaN
# 104                              India               NaN
# 105                          Indonesia               NaN
# 106                               Iran               NaN
# 107                               Iraq               NaN
# 108                            Ireland               NaN
# 109                             Israel               NaN
# 110                              Italy               NaN
# 111                            Jamaica               NaN
# 112                              Japan               NaN
# 113                             Jordan               NaN
# 114                         Kazakhstan               NaN
# 115                              Kenya               NaN
# 116                             Kosovo               NaN
# 117                             Kuwait               NaN
# 118                    Kyrgyz Republic               NaN
# 119                               Laos               NaN
# 120                             Latvia               NaN
# 121                            Lebanon               NaN
# 122                            Lesotho               NaN
# 123                            Liberia               NaN
# 124                              Libya               NaN
# 125                          Lithuania               NaN
# 126                         Luxembourg               NaN
# 127                              Macao               NaN
# 128                         Madagascar               NaN
# 129                             Malawi               NaN
# 130                           Malaysia               NaN
# 131                               Mali               NaN
# 132                         Mauritania               NaN
# 133                          Mauritius               NaN
# 134                             Mexico               NaN
# 135                            Moldova               NaN
# 136                             Monaco               NaN
# 137                           Mongolia               NaN
# 138                            Morocco               NaN
# 139                         Mozambique               NaN
# 140                            Myanmar               NaN
# 141                            Namibia               NaN
# 142                              Nepal               NaN
# 143                        Netherlands               NaN
# 144                        New Zealand               NaN
# 145                          Nicaragua               NaN
# 146                              Niger               NaN
# 147                            Nigeria               NaN
# 148                             Norway               NaN
# 149                               Oman               NaN
# 150                           Pakistan               NaN
# 151                          Palestine               NaN
# 152                             Panama               NaN
# 153                   Papua New Guinea               NaN
# 154                           Paraguay               NaN
# 155                               Peru               NaN
# 156                        Philippines               NaN
# 157                             Poland               NaN
# 158                           Portugal               NaN
# 159                        Puerto Rico               NaN
# 160                              Qatar               NaN
# 161                            Romania               NaN
# 162                             Russia               NaN
# 163                             Rwanda               NaN
# 164                         San Marino               NaN
# 165                       Saudi Arabia               NaN
# 166                            Senegal               NaN
# 167                             Serbia               NaN
# 168                         Seychelles               NaN
# 169                       Sierra Leone               NaN
# 170                          Singapore               NaN
# 171                    Slovak Republic               NaN
# 172                           Slovenia               NaN
# 173                    Solomon Islands               NaN
# 174                            Somalia               NaN
# 175                       South Africa               NaN
# 176                        South Korea               NaN
# 177                        South Sudan               NaN
# 178                              Spain               NaN
# 179                          Sri Lanka               NaN
# 180                              Sudan               NaN
# 181                           Suriname               NaN
# 182                             Sweden               NaN
# 183                        Switzerland               NaN
# 184                              Syria               NaN
# 185                             Taiwan               NaN
# 186                         Tajikistan               NaN
# 187                           Tanzania               NaN
# 188                           Thailand               NaN
# 189                        Timor-Leste               NaN
# 190                               Togo               NaN
# 191                Trinidad and Tobago               NaN
# 192                            Tunisia               NaN
# 193                             Turkey               NaN
# 194                       Turkmenistan               NaN
# 195                             Uganda               NaN
# 196                            Ukraine               NaN
# 197               United Arab Emirates               NaN
# 198                     United Kingdom               NaN
# 199                      United States               NaN
# 200                            Uruguay               NaN
# 201                         Uzbekistan               NaN
# 202                            Vanuatu               NaN
# 203                          Venezuela               NaN
# 204                            Vietnam               NaN
# 205                              Yemen               NaN
# 206                             Zambia               NaN
# 207                           Zimbabwe               NaN
# 0        United States / United States     United States
# 1     United States / Northeast Region  Northeast Region
# 2       United States / Midwest Region    Midwest Region
# 3         United States / South Region      South Region
# 4          United States / West Region       West Region
# 5              United States / Alabama           Alabama
# 6               United States / Alaska            Alaska
# 7              United States / Arizona           Arizona
# 8             United States / Arkansas          Arkansas
# 9           United States / California        California
# 10            United States / Colorado          Colorado
# 11         United States / Connecticut       Connecticut
# 12            United States / Delaware          Delaware
# 13       United States / Washington DC     Washington DC
# 14             United States / Florida           Florida
# 15             United States / Georgia           Georgia
# 16              United States / Hawaii            Hawaii
# 17               United States / Idaho             Idaho
# 18            United States / Illinois          Illinois
# 19             United States / Indiana           Indiana
# 20                United States / Iowa              Iowa
# 21              United States / Kansas            Kansas
# 22            United States / Kentucky          Kentucky
# 23           United States / Louisiana         Louisiana
# 24               United States / Maine             Maine
# 25            United States / Maryland          Maryland
# 26       United States / Massachusetts     Massachusetts
# 27            United States / Michigan          Michigan
# 28           United States / Minnesota         Minnesota
# 29         United States / Mississippi       Mississippi
# 30            United States / Missouri          Missouri
# 31             United States / Montana           Montana
# 32            United States / Nebraska          Nebraska
# 33              United States / Nevada            Nevada
# 34       United States / New Hampshire     New Hampshire
# 35          United States / New Jersey        New Jersey
# 36          United States / New Mexico        New Mexico
# 37            United States / New York          New York
# 38      United States / North Carolina    North Carolina
# 39        United States / North Dakota      North Dakota
# 40                United States / Ohio              Ohio
# 41            United States / Oklahoma          Oklahoma
# 42              United States / Oregon            Oregon
# 43        United States / Pennsylvania      Pennsylvania
# 44        United States / Rhode Island      Rhode Island
# 45      United States / South Carolina    South Carolina
# 46        United States / South Dakota      South Dakota
# 47           United States / Tennessee         Tennessee
# 48               United States / Texas             Texas
# 49                United States / Utah              Utah
# 50             United States / Vermont           Vermont
# 51            United States / Virginia          Virginia
# 52          United States / Washington        Washington
# 53       United States / West Virginia     West Virginia
# 54           United States / Wisconsin         Wisconsin
# 55             United States / Wyoming           Wyoming
# 56         United States / Puerto Rico       Puerto Rico
# 57      United States / Virgin Islands    Virgin Islands
# 0             United Kingdom / England               NaN
# 1    United Kingdom / Northern Ireland               NaN
# 2            United Kingdom / Scotland               NaN
# 3               United Kingdom / Wales               NaN

# %%
def fill_missing_values(df):
    """
    # Fill missing values by interpolation, ffill, and filling NaNs
    :param df: Dataframe to be filled
    """
    df.update(df.groupby('GeoID').ConfirmedCases.apply(
        lambda group: group.interpolate(limit_area='inside')))
    # Drop country / regions for which no number of cases is available
    df.dropna(subset=['ConfirmedCases'], inplace=True)
    df.update(df.groupby('GeoID').ConfirmedDeaths.apply(
        lambda group: group.interpolate(limit_area='inside')))
    # Drop country / regions for which no number of deaths is available
    df.dropna(subset=['ConfirmedDeaths'], inplace=True)
    for npi_column in NPI_COLUMNS:
        df.update(df.groupby('GeoID')[npi_column].ffill().fillna(0))
    return df

# %%
def prepare_dataframe(data, add_data) -> pd.DataFrame:
    """
    Loads the Oxford dataset, cleans it up and prepares the necessary columns. Depending on options, also
    loads the Johns Hopkins dataset and merges that in.
    :param data_url: the url containing the original data
    :return: a Pandas DataFrame with the historical data
    """
    # Original df from Oxford
    df1 = data

    # Additional context df (e.g Population for each country)
    df2 = add_data

    # Merge the 2 DataFrames
    df = df1.merge(df2, on=['GeoID'], how='left', suffixes=('', '_y'))

    # Drop countries with no population data
    df.dropna(subset=['Population'], inplace=True)

    #  Keep only needed columns
    columns = CONTEXT_COLUMNS + NPI_COLUMNS
    df = df[columns]

    # Fill in missing values
    df = fill_missing_values(df)
 
    # Compute number of new cases and deaths each day
    df['NewCases'] = df.groupby('GeoID').ConfirmedCases.diff().fillna(0)
    df['NewDeaths'] = df.groupby('GeoID').ConfirmedDeaths.diff().fillna(0)

    # Replace negative values (which do not make sense for these columns) with 0
    df['NewCases'] = df['NewCases'].clip(lower=0)
    df['NewDeaths'] = df['NewDeaths'].clip(lower=0)

    # Compute smoothed versions of new cases and deaths each day
    df['SmoothNewCases'] = df.groupby('GeoID')['NewCases'].rolling(
        WINDOW_SIZE, center=False).mean().fillna(0).reset_index(0, drop=True)
    df['SmoothNewDeaths'] = df.groupby('GeoID')['NewDeaths'].rolling(
        WINDOW_SIZE, center=False).mean().fillna(0).reset_index(0, drop=True)

    # Compute percent change in new cases and deaths each day
    df['CaseRatio'] = df.groupby('GeoID').SmoothNewCases.pct_change(
    ).fillna(0).replace(np.inf, 0) + 1
    df['DeathRatio'] = df.groupby('GeoID').SmoothNewDeaths.pct_change(
    ).fillna(0).replace(np.inf, 0) + 1

    # Add column for proportion of population infected
    df['ProportionInfected'] = df['ConfirmedCases'] / df['Population']

    # Create column of value to predict
    df['PredictionRatio'] = df['CaseRatio'] / (1 - df['ProportionInfected'])

    return df

# %%
d = prepare_dataframe(df, additional_context_df)  # preprocess

# %%
pd.options.display.max_rows = 4000
d.groupby(["GeoID"])["Date"].max()
# Out:
# GeoID
# Afghanistan                         2021-01-31
# Albania                             2021-01-31
# Algeria                             2021-01-31
# Andorra                             2021-01-31
# Angola                              2021-01-31
# Argentina                           2021-01-31
# Aruba                               2021-01-31
# Australia                           2021-01-31
# Austria                             2021-01-31
# Azerbaijan                          2021-01-31
# Bahamas                             2021-01-31
# Bahrain                             2021-01-31
# Bangladesh                          2021-01-31
# Barbados                            2021-01-31
# Belarus                             2021-01-31
# Belgium                             2021-01-31
# Belize                              2021-01-31
# Benin                               2021-01-31
# Bermuda                             2021-01-31
# Bhutan                              2021-01-31
# Bolivia                             2021-01-31
# Bosnia and Herzegovina              2021-01-31
# Botswana                            2021-01-31
# Brazil                              2021-01-31
# Brazil / Acre                       2021-01-31
# Brazil / Alagoas                    2021-01-31
# Brazil / Amapa                      2021-01-31
# Brazil / Amazonas                   2021-01-31
# Brazil / Bahia                      2021-01-31
# Brazil / Ceara                      2021-01-31
# Brazil / Distrito Federal           2021-01-31
# Brazil / Espirito Santo             2021-01-31
# Brazil / Goias                      2021-01-31
# Brazil / Maranhao                   2021-01-31
# Brazil / Mato Grosso                2021-01-31
# Brazil / Mato Grosso do Sul         2021-01-31
# Brazil / Minas Gerais               2021-01-31
# Brazil / Para                       2021-01-31
# Brazil / Paraiba                    2021-01-31
# Brazil / Parana                     2021-01-31
# Brazil / Pernambuco                 2021-01-31
# Brazil / Piaui                      2021-01-31
# Brazil / Rio Grande do Norte        2021-01-31
# Brazil / Rio Grande do Sul          2021-01-31
# Brazil / Rio de Janeiro             2021-01-31
# Brazil / Rondonia                   2021-01-31
# Brazil / Roraima                    2021-01-31
# Brazil / Santa Catarina             2021-01-31
# Brazil / Sao Paulo                  2021-01-31
# Brazil / Sergipe                    2021-01-31
# Brazil / Tocantins                  2021-01-31
# Brunei                              2021-01-31
# Bulgaria                            2021-01-31
# Burkina Faso                        2021-01-31
# Burundi                             2021-01-31
# Cambodia                            2021-01-31
# Cameroon                            2021-01-31
# Canada                              2021-01-31
# Cape Verde                          2021-01-31
# Central African Republic            2021-01-31
# Chad                                2021-01-31
# Chile                               2021-01-31
# China                               2021-01-31
# Colombia                            2021-01-31
# Comoros                             2021-01-31
# Congo                               2021-01-31
# Costa Rica                          2021-01-31
# Cote d'Ivoire                       2021-01-31
# Croatia                             2021-01-31
# Cuba                                2021-01-31
